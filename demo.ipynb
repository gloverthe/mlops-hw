# %%
import requests
import monitor
import os
from pathlib import Path
import sys

# Test the API 

url = "http://localhost:8000/predict"
payload = {
    "instances": [
        [5.1, 3.5, 1.4, 0.2],
        [6.2, 3.4, 5.4, 2.3]
    ]
}

resp = requests.post(url, json=payload, timeout=10)
resp.raise_for_status()
print(resp.json())


log_file = Path('logs') / 'api.log'

# View API monitoring stats
if log_file.exists():
    api_monitor = monitor.monitor(log_file=log_file)
    api_monitor.plot_stats()
    api_monitor.display_summary()
# Out:
# {'predictions': [0, 2], 'stats': {'count': 2, 'mean': 3.4375, 'std': 1.9422522364512804}, 'latency': 0.0006415843963623047}
# 📄 Reading 53 lines from logs/api.log
# ✅ Successfully parsed 22 log entries
# ⚠️ Failed to parse 31 log entries
# 📄 Reading 53 lines from logs/api.log
# ✅ Successfully parsed 22 log entries
# ⚠️ Failed to parse 31 log entries
#
# 📊 Summary Statistics:
# Total requests: 22
# Avg latency: 0.000472s
# Min latency: 0.000148s
# Max latency: 0.001479s
#
# Latest predictions: [0, 2]
