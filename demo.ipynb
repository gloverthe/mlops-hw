# %%
import requests

url = "http://localhost:8000/predict"
payload = {
    "instances": [
        [5.1, 3.5, 1.4, 0.2],
        [6.2, 3.4, 5.4, 2.3]
    ]
}

resp = requests.post(url, json=payload, timeout=10)
resp.raise_for_status()
print(resp.json())
# Out:
# {'predictions': [0, 2], 'stats': {'count': 2, 'mean': 3.4375, 'std': 1.9422522364512804}, 'latency': 0.0002429485321044922}
